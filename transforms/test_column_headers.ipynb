# %% [markdown]
# # CORE Cartridge Notebook::[transform name here]
# ![CORE Logo](assets/coreLogo.png)
#
# ---
# ## Keep in Mind
# Good Transforms Are...
# - **singular in purpose:** good transforms do one and only one thing, and handle all known cases for that thing.
# - **repeatable:** transforms should be written in a way that they can be run against the same dataset an infinate number of times and get the same result every time.
# - **easy to read:** 99 times out of 100, readable, clear code that runs a little slower is more valuable than a mess that runs quickly.
# - **No 'magic numbers':** if a variable or function is not instantly obvious as to what it is or does, without context, maybe consider renaming it.

# %% [markdown]
# ## Workflow - how to use this notebook to make science
# #### Data Science
# 1. **Document your transform.** Fill out the _description_ cell below describing what it is this transform does; this will appear in the configuration application where Ops will create, configure and update pipelines.
# 1. **Define your config object.** Fill out the _configuration_ cell below the commented-out guide to define the variables you want ops to set in the configuration application (these will populate here for every pipeline).
# 2. **Build your transformation logic.** Use the transformation cell to do that magic that you do.
# ![caution](assets/cautionTape.png)

# %% [markdown]
# ### Description
# What does this transformation do? be specific.
#
# ![what does your transform do](assets/what.gif)

# %% [markdown]
# (clear out and replace with your description)

# %% [markdown]
# ### Configuration

# %%
from core.helpers.session_helper import SessionHelper
session = SessionHelper().session
# Out:
# 2019-09-04 20:47:16,593 - core.helpers.session_helper.SessionHelper - INFO - Creating session for dev environment...
# 2019-09-04 20:47:16,637 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating administrator mocks.
# 2019-09-04 20:47:16,717 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating administrator mocks.
# 2019-09-04 20:47:16,718 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pharmaceutical company mocks.
# 2019-09-04 20:47:16,724 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pharmaceutical company mocks.
# 2019-09-04 20:47:16,726 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating brand mocks.
# 2019-09-04 20:47:16,730 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating brand mocks.
# 2019-09-04 20:47:16,733 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating segment mocks.
# 2019-09-04 20:47:16,739 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating segment mocks.
# 2019-09-04 20:47:16,742 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline type mocks.
# 2019-09-04 20:47:16,752 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline type mocks.
# 2019-09-04 20:47:16,754 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline mocks.
# 2019-09-04 20:47:16,761 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline mocks.
# 2019-09-04 20:47:16,764 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline state type mocks.
# 2019-09-04 20:47:16,770 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline state type mocks.
# 2019-09-04 20:47:16,774 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline state mocks.
# 2019-09-04 20:47:16,786 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline state mocks.
# 2019-09-04 20:47:16,788 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating tag mocks.
# 2019-09-04 20:47:16,794 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating tag mocks.
# 2019-09-04 20:47:16,797 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating transformation_template mocks.
# 2019-09-04 20:47:16,802 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation_template mocks.
# 2019-09-04 20:47:16,805 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating bridge table mocks for transformation_templates <=> tags.
# 2019-09-04 20:47:16,813 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation_templates_tags mocks.
# 2019-09-04 20:47:16,816 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating transformation mocks.
# 2019-09-04 20:47:16,826 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation mocks.
# 2019-09-04 20:47:16,828 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating transformation_variables mocks
# 2019-09-04 20:47:16,833 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation_variables mocks.
# 2019-09-04 20:47:16,839 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating run_events mocks.
# 2019-09-04 20:47:16,846 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating run_events mocks.
# 2019-09-04 20:47:16,849 - core.helpers.session_helper.SessionHelper - INFO - Done. Created dev session with mock data.

# %%
"""
************ CONFIGURATION - PLEASE TOUCH **************
Pipeline Builder configuration: creates configurations from variables specified here!!
This cell will be off in production as configurations will come from the configuration postgres DB.
"""
# config vars: this dataset
config_pharma = "pharma" # the pharmaceutical company which owns {brand}
config_brand = "brand" # the brand this pipeline operates on
config_state = "raw" # the state this transform runs in
config_name = "Template" # the name of this transform, which is the name of this notebook without .ipynb

# input vars: dataset to fetch. Recall that a contract published to S3 has a key format branch/pharma/brand/state/name
#input_pharma = "alkermes"
#input_brand = "vivitrol"
#input_state = "ingest"
#input_name = "patient_status_standardize_numbers"
#input_branch = "ds-321" # if None, input_branch is automagically set to your working branch

input_pharma = "sun"
input_brand = "ilumya"
input_state = "ingest"
input_name = "patient_status_ingest_column_mapping"
input_branch = "longitudal-id" # if None, input_branch is automagically set to your working branch

# %%
"""
************ SETUP - DON'T TOUCH **************
Populating config mocker based on config parameters...
"""
import core.helpers.pipeline_builder as builder

ids = builder.build(config_pharma, config_brand, config_state, config_name, session)
transform_id = ids[0]
run_id = ids[1]
# Out:
# 2019-09-04 20:56:22,048 - core.logging - DEBUG - Adding/getting mocks for specified configurations...
# 2019-09-04 20:56:22,075 - core.logging - DEBUG - Done. Creating mock run event and committing results to configuration mocker.

# %%
"""
************ SETUP - DON'T TOUCH **************
This section imports data from the configuration database
and should not need to be altered or otherwise messed with. 
~~These are not the droids you are looking for~~
"""
from core.constants import BRANCH_NAME, ENV_BUCKET
from core.helpers.session_helper import SessionHelper
from core.models.configuration import Transformation
from dataclasses import dataclass
from core.dataset_contract import DatasetContract

db_transform = session.query(Transformation).filter(Transformation.id == transform_id).one()

@dataclass
class DbTransform:
    id: int = db_transform.id ## the instance id of the transform in the config app
    name: str = db_transform.transformation_template.name ## the transform name in the config app
    state: str = db_transform.pipeline_state.pipeline_state_type.name ## the pipeline state, one of raw, ingest, master, enhance, enrich, metrics, dimensional
    branch:str = BRANCH_NAME ## the git branch for this execution 
    brand: str = db_transform.pipeline_state.pipeline.brand.name ## the pharma brand name
    pharmaceutical_company: str = db_transform.pipeline_state.pipeline.brand.pharmaceutical_company.name # the pharma company name
    publish_contract: DatasetContract = DatasetContract(branch=BRANCH_NAME,
                            state=db_transform.pipeline_state.pipeline_state_type.name,
                            parent=db_transform.pipeline_state.pipeline.brand.pharmaceutical_company.name,
                            child=db_transform.pipeline_state.pipeline.brand.name,
                            dataset=db_transform.transformation_template.name)

# %%
""" 
********* VARIABLES - PLEASE TOUCH ********* 
This section defines what you expect to get from the configuration application 
in a single "transform" object. Define the vars you need here, and comment inline to the right of them 
for all-in-one documentation. 
Engineering will build a production "transform" object for every pipeline that matches what you define here.

@@@ FORMAT OF THE DATA CLASS IS: @@@ 

<variable_name>: <data_type> #<comment explaining what the value is to future us>

e.g.

class Transform(DbTransform):
    some_ratio: float
    site_name: str

~~These ARE the droids you are looking for~~
"""

class Transform(DbTransform):
    '''
    YOUR properties go here!!
    Variable properties should be assigned to the exact name of
    the transformation as it appears in the Jupyter notebook filename.
    '''

transform = Transform()

# %%
## Please place your value assignments for development here!!
## This cell will be turned off in production and Engineering will set to pull from the configuration application instead
## For the last example, this could look like...
## transform.some_ratio = 0.6
## transform.site_name = "WALGREENS"

# %% [markdown]
# ### Transformation

# %%
"""
************ FETCH DATA - TOUCH, BUT CAREFULLY **************
This cell will be turned off in production, as the input_contract will be handled by the pipeline.
"""

if not input_branch:
    input_branch = BRANCH_NAME
input_contract = DatasetContract(branch=input_branch, state=input_state, parent=input_pharma, child=input_brand, dataset=input_name)
run_filter = []
# run_filter.append(dict(partition="run_id", comparison="==", values=[1]))
# IF YOU HAVE PUBLISHED DATA MULTIPLE TIMES, uncomment the above line and change the int to the run_id to fetch.
# Otherwise, you will have duplicate values in your fetched dataset!
sun = input_contract.fetch(filters=run_filter)
# Out:
# 2019-09-04 20:56:25,293 - core.dataset_contract.DatasetContract - INFO - Fetching dataframe from s3 location s3://ichain-dev/longitudal-id/sun/ilumya/ingest/patient_status_ingest_column_mapping.
# /usr/local/lib/python3.6/site-packages/s3parq/fetch_parq.py:394: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat(temp_frames)

# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_columns', 150)
pd.set_option('display.max_rows', 500)

# %%
sun.head()
# Out:
#   __metadata_app_version                         __metadata_output_contract  \
# 0                 0.0.11  s3://ichain-dev/longitudal-id/sun/ilumya/inges...
# 1                 0.0.11  s3://ichain-dev/longitudal-id/sun/ilumya/inges...
# 2                 0.0.11  s3://ichain-dev/longitudal-id/sun/ilumya/inges...
# 3                 0.0.11  s3://ichain-dev/longitudal-id/sun/ilumya/inges...
# 4                 0.0.11  s3://ichain-dev/longitudal-id/sun/ilumya/inges...
#
#    __metadata_run_id __metadata_run_timestamp __metadata_transform_timestamp  \
# 0                  1      2019-08-19 19:48:40            2019-08-19 19:52:24
# 1                  1      2019-08-19 19:48:40            2019-08-19 19:52:24
# 2                  1      2019-08-19 19:48:40            2019-08-19 19:52:24
# 3                  1      2019-08-19 19:48:40            2019-08-19 19:52:24
# 4                  1      2019-08-19 19:48:40            2019-08-19 19:52:24
#
#   aggregator_transaction_id brand bridge_patient bridge_quantity_dispensed  \
# 0
# 1
# 2
# 3
# 4
#
#   bridge_quantity_dispensed_2 copay_as_amount customer_status  \
# 0                                        None       CANCELLED
# 1                                        None       CANCELLED
# 2                                        None       CANCELLED
# 3                                        None       CANCELLED
# 4                                        None       CANCELLED
#
#   customer_status_description customer_substatus days_supply dose_count  \
# 0                 Patient End                             28
# 1                 Patient End                             84
# 2                 Patient End                             84
# 3                 Patient End                             28
# 4                 Patient End                             84
#
#   dose_exchange_count dose_exchange_flag dose_titration_count  \
# 0
# 1
# 2
# 3
# 4
#
#   dose_titration_quantity   dx_1  dx_2 enroll_received_date  \
# 0                          L40.0  None
# 1                          L40.0  None
# 2                          L40.0  None
# 3                          L40.0  None
# 4                          L40.0  None
#
#   fitness_for_duty_request_flag fitness_for_duty_ship_date  \
# 0
# 1
# 2
# 3
# 4
#
#   has_medical_coverage_flag          hcp_address_1 hcp_address_2 hcp_city  \
# 0                         N  9015 US HIGHWAY 301 N          None  PARRISH
# 1                         N  9015 US HIGHWAY 301 N          None  PARRISH
# 2                         N  9015 US HIGHWAY 301 N          None  PARRISH
# 3                         N  9015 US HIGHWAY 301 N          None  PARRISH
# 4                         N  9015 US HIGHWAY 301 N          None  PARRISH
#
#   hcp_dea_number hcp_facility hcp_first_name hcp_last_name hcp_middle_name  \
# 0           None         None          BRETT         BLAKE
# 1           None         None          BRETT         BLAKE
# 2           None         None          BRETT         BLAKE
# 3           None         None          BRETT         BLAKE
# 4           None         None          BRETT         BLAKE
#
#       hcp_npi   hcp_phone hcp_specialty hcp_state hcp_state_license_number  \
# 0  1376772707  9417761577                      FL
# 1  1376772707  9417761577                      FL
# 2  1376772707  9417761577                      FL
# 3  1376772707  9417761577                      FL
# 4  1376772707  9417761577                      FL
#
#   hcp_suffix hcp_zip hub_patient hub_patient_id longitudinal_patient_id  \
# 0              34219                       None
# 1              34219                       None
# 2              34219                       None
# 3              34219                       None
# 4              34219                       None
#
#                 medication          ndc other_payer_amount oxygen_flag  \
# 0  ILUMYA 100MG/ML PFS INJ  47335017795               None
# 1  ILUMYA 100MG/ML PFS INJ  47335017795               None
# 2  ILUMYA 100MG/ML PFS INJ  47335017795               None
# 3  ILUMYA 100MG/ML PFS INJ  47335017795               None
# 4  ILUMYA 100MG/ML PFS INJ  47335017795               None
#
#   patient_consent_date patient_dob patient_gender patient_oop_program_name  \
# 0                             None              F
# 1                             None              F
# 2                             None              F
# 3                             None              F
# 4                             None              F
#
#   patient_state patient_support_1 patient_support_2 patient_zip  \
# 0          None                                              34
# 1          None                                              34
# 2          None                                              34
# 3          None                                              34
# 4          None                                              34
#
#   pharmacy_address_1 pharmacy_address_2 pharmacy_city pharmacy_code  \
# 0
# 1
# 2
# 3
# 4
#
#   pharmacy_dea_number pharmacy_hin pharmacy_name pharmacy_ncpdp pharmacy_npi  \
# 0                                            BRV                  1083045140
# 1                                            BRV                  1083045140
# 2                                            BRV                  1083045140
# 3                                            BRV                  1083045140
# 4                                            BRV                  1083045140
#
#   pharmacy_parent_name pharmacy_patient_id pharmacy_state  \
# 0                                406800804
# 1                                406800804
# 2                                406800804
# 3                                406800804
# 4                                406800804
#
#        pharmacy_transaction_id pharmacy_zip prev_dispensed primary_coins  \
# 0  BRIOVARX_20190819_144786231                        None
# 1  BRIOVARX_20190819_144786233                        None
# 2  BRIOVARX_20190819_144786232                        None
# 3  BRIOVARX_20190819_144786231                        None
# 4  BRIOVARX_20190819_144786233                        None
#
#   primary_copay primary_cost_amount primary_cost_type primary_coverage_type  \
# 0          None                                                    PHARMACY
# 1          None                                                    PHARMACY
# 2          None                                                    PHARMACY
# 3          None                                                    PHARMACY
# 4          None                                                    PHARMACY
#
#   primary_deductible primary_patient_responsibility primary_payer  \
# 0                                                     UHC C AND S
# 1                                                     UHC C AND S
# 2                                                     UHC C AND S
# 3                                                     UHC C AND S
# 4                                                     UHC C AND S
#
#   primary_payer_bin primary_payer_group primary_payer_iin primary_payer_pcn  \
# 0
# 1
# 2
# 3
# 4
#
#   primary_payer_subtype primary_payer_type primary_pbm_name primary_plan  \
# 0                               MEDICARE D
# 1                               MEDICARE D
# 2                               MEDICARE D
# 3                               MEDICARE D
# 4                               MEDICARE D
#
#   primary_plan_paid primary_plan_type primary_prior_auth_expiration_date  \
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
#
#   primary_prior_auth_required_flag prior_therapy_name quantity_dispensed  \
# 0                                                                      1
# 1                                                                      1
# 2                                                                      1
# 3                                                                      1
# 4                                                                      1
#
#       referral_date referral_number referral_source restatement_flag  \
# 0  2019080609:35:15                          DIRECT
# 1  2019080609:35:15                          DIRECT
# 2  2019080609:35:15                          DIRECT
# 3  2019080609:35:15                          DIRECT
# 4  2019080609:35:15                          DIRECT
#
#     rx_date rx_fill_number rx_fills rx_number rx_refills_remaining  \
# 0  20190422             00       00                           None
# 1  20190422             00       05                           None
# 2  20190422             00       00                           None
# 3  20190422             00       00                           None
# 4  20190422             00       05                           None
#
#   secondary_coins secondary_copay secondary_coverage_type  \
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
#
#   secondary_deductible secondary_patient_responsibility secondary_payer  \
# 0                                                                  None
# 1                                                                  None
# 2                                                                  None
# 3                                                                  None
# 4                                                                  None
#
#   secondary_payer_bin secondary_payer_flag secondary_payer_group  \
# 0
# 1
# 2
# 3
# 4
#
#   secondary_payer_iin secondary_payer_pcn secondary_payer_subtype  \
# 0
# 1
# 2
# 3
# 4
#
#   secondary_payer_type secondary_plan secondary_plan_paid secondary_plan_type  \
# 0                 None
# 1                 None
# 2                 None
# 3                 None
# 4                 None
#
#   ship_address_1 ship_address_2 ship_carrier ship_city ship_date  \
# 0           None                        None      None      None
# 1           None                        None      None      None
# 2           None                        None      None      None
# 3           None                        None      None      None
# 4           None                        None      None      None
#
#   ship_location ship_state ship_tracking_id ship_zip status       status_date  \
# 0          None       None             None     None         2019081821:52:26
# 1          None       None             None     None         2019081821:52:26
# 2          None       None             None     None         2019081821:52:26
# 3          None       None             None     None         2019081821:52:26
# 4          None       None             None     None         2019081821:52:26
#
#   substatus  transaction_date transaction_sequence transaction_type  \
# 0            2019081907:06:51                    0              COM
# 1            2019081907:06:51                    0              COM
# 2            2019081907:06:51                    0              COM
# 3            2019081907:06:51                    0              COM
# 4            2019081907:06:51                    0              COM
#
#   transfer_pharmacy triage_date uom_dispensed
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None

# %%
### Use the variables above to execute your transformation. the final output needs to be a variable named final_dataframe

# %% [markdown]
# ### Publish

# %%
## that's it - just provide the final dataframe to the var final_dataframe and we take it from there
transform.publish_contract.publish(final_dataframe, run_id, session)
session.close()
