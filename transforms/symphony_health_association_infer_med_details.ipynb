# %%
transform_id = 15

# %%
"""
************ SETUP - DON'T TOUCH **************
This section imports data from the configuration database
and should not need to be altered, molested or otherwise messed with. 
~~These are not the droids you are looking for~~
"""
from core.constants import BRANCH_NAME, ENV_BUCKET
from core.helpers.session_helper import SessionHelper
from core.models.configuration import Transformation
from dataclasses import dataclass
from core.dataset_contract import DatasetContract
import pandas as pd

db_transform = SessionHelper().session.query(Transformation).filter(Transformation.id == transform_id).one()

@dataclass
class DbTransform:
    id: int = db_transform.id ## the instance id of the transform in the config app
    name: str = db_transform.transformation_template.name ## the transform name in the config app
    state: str = db_transform.pipeline_state.pipeline_state_type.name ## the pipeline state, one of raw, ingest, master, enhance, enrich, metrics, dimensional
    branch: str = "schafrn"
    #branch: str = BRANCH_NAME ## the git branch for this execution 
    brand: str = db_transform.pipeline_state.pipeline.brand.name ## the pharma brand name
    pharmaceutical_company: str = db_transform.pipeline_state.pipeline.brand.pharmaceutical_company.name # the pharma company name
    publish_contract: DatasetContract = DatasetContract(branch=BRANCH_NAME,
                            state=db_transform.pipeline_state.pipeline_state_type.name,
                            parent=db_transform.pipeline_state.pipeline.brand.pharmaceutical_company.name,
                            child=db_transform.pipeline_state.pipeline.brand.name,
                            dataset=db_transform.transformation_template.name)
# Out:
# 2019-05-28 18:35:58,106 - core.helpers.session_helper.SessionHelper - INFO - Creating session for dev environment...
# 2019-05-28 18:35:58,128 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating administrator mocks.
# 2019-05-28 18:35:58,158 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating administrator mocks.
# 2019-05-28 18:35:58,159 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pharmaceutical company mocks.
# 2019-05-28 18:35:58,163 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pharmaceutical company mocks.
# 2019-05-28 18:35:58,164 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating brand mocks.
# 2019-05-28 18:35:58,168 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating brand mocks.
# 2019-05-28 18:35:58,169 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating segment mocks.
# 2019-05-28 18:35:58,172 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating segment mocks.
# 2019-05-28 18:35:58,173 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline type mocks.
# 2019-05-28 18:35:58,177 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline type mocks.
# 2019-05-28 18:35:58,178 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline mocks.
# 2019-05-28 18:35:58,183 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline mocks.
# 2019-05-28 18:35:58,184 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline state type mocks.
# 2019-05-28 18:35:58,187 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline state type mocks.
# 2019-05-28 18:35:58,188 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline state mocks.
# 2019-05-28 18:35:58,197 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline state mocks.
# 2019-05-28 18:35:58,198 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating tag mocks.
# 2019-05-28 18:35:58,202 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating tag mocks.
# 2019-05-28 18:35:58,204 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating transformation_template mocks.
# 2019-05-28 18:35:58,210 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation_template mocks.
# 2019-05-28 18:35:58,210 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating bridge table mocks for transformation_templates <=> tags.
# 2019-05-28 18:35:58,213 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation_templates_tags mocks.
# 2019-05-28 18:35:58,214 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating transformation mocks.
# 2019-05-28 18:35:58,228 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation mocks.
# 2019-05-28 18:35:58,229 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating transformation_variables mocks
# 2019-05-28 18:35:58,296 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation_variables mocks.
# 2019-05-28 18:35:58,297 - core.helpers.session_helper.SessionHelper - INFO - Done. Created dev session with mock data.

# %% [markdown]
# # CORE Cartridge Notebook::[transform name here]
# ![CORE Logo](assets/coreLogo.png)
#
# ---
# ## Keep in Mind
# Good Transforms Are...
# - **singular in purpose:** good transforms do one and only one thing, and handle all known cases for that thing.
# - **repeatable:** transforms should be written in a way that they can be run against the same dataset an infinate number of times and get the same result every time.
# - **easy to read:** 99 times out of 100, readable, clear code that runs a little slower is more valuable than a mess that runs quickly.
# - **No 'magic numbers':** if a variable or function is not instantly obvious as to what it is or does, without context, maybe consider renaming it.

# %% [markdown]
# ## Workflow - how to use this notebook to make science
# #### Data Science
# 1. **Document your transform.** Fill out the _description_ cell below describing what it is this transform does; this will appear in the configuration application where Ops will create, configure and update pipelines.
# 1. **Define your config object.** Fill out the _configuration_ cell below the commented-out guide to define the variables you want ops to set in the configuration application (these will populate here for every pipeline).
# 2. **Build your transformation logic.** Use the transformation cell to do that magic that you do.
# ![caution](assets/cautionTape.png)

# %% [markdown]
# ### Configuration

# %%
""" 
********* CONFIGURATION - PLEASE TOUCH ********* 
This section defines what you expect to get from the configuration application 
in a single "transform" object. Define the vars you need here, and comment inline to the right of them 
for all-in-one documentation. 
Engineering will build a production "transform" object for every pipeline that matches what you define here.

@@@ FORMAT OF THE DATA CLASS IS: @@@ 

<value_name>: <data_type> #<comment explaining what the value is to future us>

~~These ARE the droids you are looking for~~
"""

class Transform(DbTransform):
        input_transform: str = db_transform.variables.input_transform # The name of the transform to input source data from
        ## YOUR properties go here!!

# %%
## Please place your value assignments for development here!!
## This cell will be turned off in production and Engineering will set to pull form the configuration application instead

transform = Transform()
transform.input_transform = "symphony_health_association_filter_to_brand"

# %% [markdown]
# ### Description
# What does this transformation do? be specific.
#
# ![what does your transform do](assets/what.gif)

# %% [markdown]
# This transformation infers details about medication type based on brand name, and adds a field stating if the rx type is fill (R) or no fill (N)

# %% [markdown]
# ### Transformation

# %%
### Retrieve current dataset from contract
from core.dataset_diff import DatasetDiff

#deleteme = cc.get_relative_contract(t_name=transform.input_transform, contract=transform.publish_contract)
#final_dataframe = s3parq.fetch_parq.fetch(bucket=deleteme.bucket, key=deleteme.key)
diff = DatasetDiff(db_transform.id)
final_dataframe = diff.get_diff(transform_name=transform.input_transform)
# Out:
# 2019-05-28 18:36:01,297 - core.helpers.session_helper.SessionHelper - INFO - Creating session for dev environment...
# 2019-05-28 18:36:01,320 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating administrator mocks.
# 2019-05-28 18:36:01,324 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating administrator mocks.
# 2019-05-28 18:36:01,325 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pharmaceutical company mocks.
# 2019-05-28 18:36:01,328 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pharmaceutical company mocks.
# 2019-05-28 18:36:01,330 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating brand mocks.
# 2019-05-28 18:36:01,333 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating brand mocks.
# 2019-05-28 18:36:01,334 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating segment mocks.
# 2019-05-28 18:36:01,340 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating segment mocks.
# 2019-05-28 18:36:01,341 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline type mocks.
# 2019-05-28 18:36:01,344 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline type mocks.
# 2019-05-28 18:36:01,346 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline mocks.
# 2019-05-28 18:36:01,351 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline mocks.
# 2019-05-28 18:36:01,352 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline state type mocks.
# 2019-05-28 18:36:01,356 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline state type mocks.
# 2019-05-28 18:36:01,357 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline state mocks.
# 2019-05-28 18:36:01,365 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline state mocks.
# 2019-05-28 18:36:01,366 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating tag mocks.
# 2019-05-28 18:36:01,369 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating tag mocks.
# 2019-05-28 18:36:01,370 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating transformation_template mocks.
# 2019-05-28 18:36:01,378 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation_template mocks.
# 2019-05-28 18:36:01,379 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating bridge table mocks for transformation_templates <=> tags.
# 2019-05-28 18:36:01,383 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation_templates_tags mocks.
# 2019-05-28 18:36:01,384 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating transformation mocks.
# 2019-05-28 18:36:01,396 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation mocks.
# 2019-05-28 18:36:01,397 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating transformation_variables mocks
# 2019-05-28 18:36:01,456 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation_variables mocks.
# 2019-05-28 18:36:01,457 - core.helpers.session_helper.SessionHelper - INFO - Done. Created dev session with mock data.
# 2019-05-28 18:36:01,466 - core.helpers.session_helper.SessionHelper - INFO - Creating session for dev environment...
# 2019-05-28 18:36:01,479 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating administrator mocks.
# 2019-05-28 18:36:01,484 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating administrator mocks.
# 2019-05-28 18:36:01,485 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pharmaceutical company mocks.
# 2019-05-28 18:36:01,489 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pharmaceutical company mocks.
# 2019-05-28 18:36:01,490 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating brand mocks.
# 2019-05-28 18:36:01,493 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating brand mocks.
# 2019-05-28 18:36:01,494 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating segment mocks.
# 2019-05-28 18:36:01,497 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating segment mocks.
# 2019-05-28 18:36:01,498 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline type mocks.
# 2019-05-28 18:36:01,500 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline type mocks.
# 2019-05-28 18:36:01,502 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline mocks.
# 2019-05-28 18:36:01,506 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline mocks.
# 2019-05-28 18:36:01,507 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline state type mocks.
# 2019-05-28 18:36:01,511 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline state type mocks.
# 2019-05-28 18:36:01,512 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline state mocks.
# 2019-05-28 18:36:01,520 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline state mocks.
# 2019-05-28 18:36:01,521 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating tag mocks.
# 2019-05-28 18:36:01,525 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating tag mocks.
# 2019-05-28 18:36:01,526 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating transformation_template mocks.
# 2019-05-28 18:36:01,533 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation_template mocks.
# 2019-05-28 18:36:01,534 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating bridge table mocks for transformation_templates <=> tags.
# 2019-05-28 18:36:01,537 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation_templates_tags mocks.
# 2019-05-28 18:36:01,538 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating transformation mocks.
# 2019-05-28 18:36:01,552 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation mocks.
# 2019-05-28 18:36:01,553 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating transformation_variables mocks
# 2019-05-28 18:36:01,615 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation_variables mocks.
# 2019-05-28 18:36:01,616 - core.helpers.session_helper.SessionHelper - INFO - Done. Created dev session with mock data.

# %%
final_dataframe.head()
# Out:
#          rec_date pharm_code   pharm_npi transtype pharm_transaction_id  \
# 0  20181024115959    ACCREDO  1346208949       COM   279133432018102401
# 1  20181025115959    ACCREDO  1346208949       COM   278370982018102502
# 2  20181029115959    ACCREDO  1346208949       COM   279181482018102903
# 3  20181102115959    ACCREDO  1346208949       COM   267244982018110204
# 4  20181106115959    ACCREDO  1346208949       COM   160618142018110605
#
#   trans_seq ref_source        ref_date program_id pharmacy_id  ...  \
# 0         0     DIRECT  20181019120000       None    27913343  ...
# 1         0     DIRECT  20181022120000       None    27837098  ...
# 2         0     DIRECT  20181024120000       None    27918148  ...
# 3         0     DIRECT  20181030120000       None    26724498  ...
# 4         0     DIRECT  20181102120000       None    16061814  ...
#
#   oth_payer_amt xfer_pharmname msa_patient_id msa_patient_bmap  \
# 0          None           None           None            NNNNV
# 1          None           None           None            NNNVV
# 2          None           None           None            NNNVV
# 3          None           None           None            NNNVV
# 4          None           None           None            NNNVV
#
#   __metadata_app_version                         __metadata_output_contract  \
# 0                 0.0.11  s3://ichain-dev/stephanie/stephanie/ilumya/mas...
# 1                 0.0.11  s3://ichain-dev/stephanie/stephanie/ilumya/mas...
# 2                 0.0.11  s3://ichain-dev/stephanie/stephanie/ilumya/mas...
# 3                 0.0.11  s3://ichain-dev/stephanie/stephanie/ilumya/mas...
# 4                 0.0.11  s3://ichain-dev/stephanie/stephanie/ilumya/mas...
#
#   brand strength prod_grp_id __metadata_run_timestamp
# 0  None     None         NaN      2019-05-28 16:02:58
# 1  None     None         NaN      2019-05-28 16:02:58
# 2  None     None         NaN      2019-05-28 16:02:58
# 3  None     None         NaN      2019-05-28 16:02:58
# 4  None     None         NaN      2019-05-28 16:02:58
#
# [5 rows x 73 columns]

# %%
### Use the variables above to execute your transformation. the final output needs to be a variable named final_dataframe

def infer_uom(med: str):
    if not med:
        return ''
    
    if 'ILUMYA' in med.upper():
        return 'PEN'
    
    elif 'ODOMZO' in med.upper():
        return 'CAPSULE'

    else:
        return 'UNKNOWN'
    

def infer_rx_type(fills: str):
    if not fills:
        return ''
    
    if int(fills) == 0:
        return 'N'
    
    else:
        return 'R'

final_dataframe['uom'] = final_dataframe['medication'].apply(infer_uom)
final_dataframe['rx_type'] = final_dataframe['rxfill'].apply(infer_rx_type)

# %% [markdown]
# ### Publish

# %%
## that's it - just provide the final dataframe to the var final_dataframe and we take it from there
transform.publish_contract.publish(final_dataframe)
# Out:
# 2019-05-28 18:36:08,245 - core.dataset_contract.DatasetContract - INFO - Publishing dataframe to s3 location s3://ichain-dev/stephanie/stephanie/ilumya/master/symphony_health_association_infer_med_details.
# 2019-05-28 18:36:08,249 - s3parq.publish_parq - INFO - Checking params...
# 2019-05-28 18:36:08,254 - s3parq.publish_parq - INFO - Params valid.
# 2019-05-28 18:36:08,276 - s3parq.publish_parq - INFO - Writing to S3...
