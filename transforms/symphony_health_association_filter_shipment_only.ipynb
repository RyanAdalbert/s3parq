# %%
"""
************ SETUP - DON'T TOUCH **************
This section imports data from the configuration database
and should not need to be altered, molested or otherwise messed with. 
~~These are not the droids you are looking for~~
"""
from core.constants import BRANCH_NAME, ENV_BUCKET
from core.helpers.session_helper import SessionHelper
from core.models.configuration import Transformation
from dataclasses import dataclass
from core.dataset_contract import DatasetContract
import pandas as pd

db_transform = SessionHelper().session.query(Transformation).filter(Transformation.id == transform_id).one()

@dataclass
class DbTransform:
    id: int = db_transform.id ## the instance id of the transform in the config app
    name: str = db_transform.transformation_template.name ## the transform name in the config app
    state: str = db_transform.pipeline_state.pipeline_state_type.name ## the pipeline state, one of raw, ingest, master, enhance, enrich, metrics, dimensional
    branch: str = BRANCH_NAME ## the git branch for this execution 
    brand: str = db_transform.pipeline_state.pipeline.brand.name ## the pharma brand name
    pharmaceutical_company: str = db_transform.pipeline_state.pipeline.brand.pharmaceutical_company.name # the pharma company name
    publish_contract: DatasetContract = DatasetContract(branch=BRANCH_NAME,
                            state=db_transform.pipeline_state.pipeline_state_type.name,
                            parent=db_transform.pipeline_state.pipeline.brand.pharmaceutical_company.name,
                            child=db_transform.pipeline_state.pipeline.brand.name,
                            dataset=db_transform.transformation_template.name)
# Out:
# 2019-05-28 18:36:39,946 - core.helpers.session_helper.SessionHelper - INFO - Creating session for dev environment...
# 2019-05-28 18:36:39,969 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating administrator mocks.
# 2019-05-28 18:36:40,003 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating administrator mocks.
# 2019-05-28 18:36:40,005 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pharmaceutical company mocks.
# 2019-05-28 18:36:40,008 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pharmaceutical company mocks.
# 2019-05-28 18:36:40,009 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating brand mocks.
# 2019-05-28 18:36:40,012 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating brand mocks.
# 2019-05-28 18:36:40,013 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating segment mocks.
# 2019-05-28 18:36:40,016 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating segment mocks.
# 2019-05-28 18:36:40,017 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline type mocks.
# 2019-05-28 18:36:40,020 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline type mocks.
# 2019-05-28 18:36:40,020 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline mocks.
# 2019-05-28 18:36:40,025 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline mocks.
# 2019-05-28 18:36:40,026 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline state type mocks.
# 2019-05-28 18:36:40,030 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline state type mocks.
# 2019-05-28 18:36:40,031 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline state mocks.
# 2019-05-28 18:36:40,037 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline state mocks.
# 2019-05-28 18:36:40,038 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating tag mocks.
# 2019-05-28 18:36:40,041 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating tag mocks.
# 2019-05-28 18:36:40,042 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating transformation_template mocks.
# 2019-05-28 18:36:40,048 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation_template mocks.
# 2019-05-28 18:36:40,049 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating bridge table mocks for transformation_templates <=> tags.
# 2019-05-28 18:36:40,052 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation_templates_tags mocks.
# 2019-05-28 18:36:40,053 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating transformation mocks.
# 2019-05-28 18:36:40,073 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation mocks.
# 2019-05-28 18:36:40,074 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating transformation_variables mocks
# 2019-05-28 18:36:40,136 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation_variables mocks.
# 2019-05-28 18:36:40,138 - core.helpers.session_helper.SessionHelper - INFO - Done. Created dev session with mock data.

# %% [markdown]
# # CORE Cartridge Notebook::[transform name here]
# ![CORE Logo](assets/coreLogo.png)
#
# ---
# ## Keep in Mind
# Good Transforms Are...
# - **singular in purpose:** good transforms do one and only one thing, and handle all known cases for that thing.
# - **repeatable:** transforms should be written in a way that they can be run against the same dataset an infinate number of times and get the same result every time.
# - **easy to read:** 99 times out of 100, readable, clear code that runs a little slower is more valuable than a mess that runs quickly.
# - **No 'magic numbers':** if a variable or function is not instantly obvious as to what it is or does, without context, maybe consider renaming it.

# %% [markdown]
# ## Workflow - how to use this notebook to make science
# #### Data Science
# 1. **Document your transform.** Fill out the _description_ cell below describing what it is this transform does; this will appear in the configuration application where Ops will create, configure and update pipelines.
# 1. **Define your config object.** Fill out the _configuration_ cell below the commented-out guide to define the variables you want ops to set in the configuration application (these will populate here for every pipeline).
# 2. **Build your transformation logic.** Use the transformation cell to do that magic that you do.
# ![caution](assets/cautionTape.png)

# %% [markdown]
# ### Configuration

# %%
""" 
********* CONFIGURATION - PLEASE TOUCH ********* 
This section defines what you expect to get from the configuration application 
in a single "transform" object. Define the vars you need here, and comment inline to the right of them 
for all-in-one documentation. 
Engineering will build a production "transform" object for every pipeline that matches what you define here.

@@@ FORMAT OF THE DATA CLASS IS: @@@ 

<value_name>: <data_type> #<comment explaining what the value is to future us>

~~These ARE the droids you are looking for~~
"""

class Transform(DbTransform):
        input_transform: str = db_transform.variables.input_transform # The name of the transform to input source data from
        ## YOUR properties go here!!

# %%
## Please place your value assignments for development here!!
## This cell will be turned off in production and Engineering will set to pull form the configuration application instead

transform = Transform()
#transform.input_transform = "symphony_health_association_remap_pharm_codes"

# %% [markdown]
# ### Description
# What does this transformation do? be specific.
#
# ![what does your transform do](assets/what.gif)

# %% [markdown]
# This transformation filters the data to shipped products only. It also performs some basic formatting on the ship_date field

# %% [markdown]
# ### Transformation

# %%
### Retrieve current dataset from contract
from core.dataset_diff import DatasetDiff

#deleteme = cc.get_relative_contract(t_name=transform.input_transform, contract=transform.publish_contract)
#final_dataframe = s3parq.fetch_parq.fetch(bucket=deleteme.bucket, key=deleteme.key)
diff = DatasetDiff(db_transform.id)
final_dataframe = diff.get_diff(transform_name=transform.input_transform)
# Out:
# 2019-05-28 18:36:42,385 - core.helpers.session_helper.SessionHelper - INFO - Creating session for dev environment...
# 2019-05-28 18:36:42,397 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating administrator mocks.
# 2019-05-28 18:36:42,401 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating administrator mocks.
# 2019-05-28 18:36:42,402 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pharmaceutical company mocks.
# 2019-05-28 18:36:42,406 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pharmaceutical company mocks.
# 2019-05-28 18:36:42,407 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating brand mocks.
# 2019-05-28 18:36:42,410 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating brand mocks.
# 2019-05-28 18:36:42,412 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating segment mocks.
# 2019-05-28 18:36:42,418 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating segment mocks.
# 2019-05-28 18:36:42,420 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline type mocks.
# 2019-05-28 18:36:42,423 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline type mocks.
# 2019-05-28 18:36:42,427 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline mocks.
# 2019-05-28 18:36:42,444 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline mocks.
# 2019-05-28 18:36:42,447 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline state type mocks.
# 2019-05-28 18:36:42,463 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline state type mocks.
# 2019-05-28 18:36:42,469 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline state mocks.
# 2019-05-28 18:36:42,479 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline state mocks.
# 2019-05-28 18:36:42,480 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating tag mocks.
# 2019-05-28 18:36:42,483 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating tag mocks.
# 2019-05-28 18:36:42,485 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating transformation_template mocks.
# 2019-05-28 18:36:42,491 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation_template mocks.
# 2019-05-28 18:36:42,492 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating bridge table mocks for transformation_templates <=> tags.
# 2019-05-28 18:36:42,495 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation_templates_tags mocks.
# 2019-05-28 18:36:42,496 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating transformation mocks.
# 2019-05-28 18:36:42,509 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation mocks.
# 2019-05-28 18:36:42,511 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating transformation_variables mocks
# 2019-05-28 18:36:42,583 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation_variables mocks.
# 2019-05-28 18:36:42,584 - core.helpers.session_helper.SessionHelper - INFO - Done. Created dev session with mock data.
# 2019-05-28 18:36:42,595 - core.helpers.session_helper.SessionHelper - INFO - Creating session for dev environment...
# 2019-05-28 18:36:42,613 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating administrator mocks.
# 2019-05-28 18:36:42,618 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating administrator mocks.
# 2019-05-28 18:36:42,619 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pharmaceutical company mocks.
# 2019-05-28 18:36:42,621 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pharmaceutical company mocks.
# 2019-05-28 18:36:42,623 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating brand mocks.
# 2019-05-28 18:36:42,634 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating brand mocks.
# 2019-05-28 18:36:42,636 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating segment mocks.
# 2019-05-28 18:36:42,641 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating segment mocks.
# 2019-05-28 18:36:42,642 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline type mocks.
# 2019-05-28 18:36:42,647 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline type mocks.
# 2019-05-28 18:36:42,648 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline mocks.
# 2019-05-28 18:36:42,653 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline mocks.
# 2019-05-28 18:36:42,654 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline state type mocks.
# 2019-05-28 18:36:42,658 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline state type mocks.
# 2019-05-28 18:36:42,659 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating pipeline state mocks.
# 2019-05-28 18:36:42,665 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating pipeline state mocks.
# 2019-05-28 18:36:42,666 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating tag mocks.
# 2019-05-28 18:36:42,669 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating tag mocks.
# 2019-05-28 18:36:42,670 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating transformation_template mocks.
# 2019-05-28 18:36:42,676 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation_template mocks.
# 2019-05-28 18:36:42,676 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating bridge table mocks for transformation_templates <=> tags.
# 2019-05-28 18:36:42,679 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation_templates_tags mocks.
# 2019-05-28 18:36:42,680 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating transformation mocks.
# 2019-05-28 18:36:42,694 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation mocks.
# 2019-05-28 18:36:42,695 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Generating transformation_variables mocks
# 2019-05-28 18:36:42,761 - core.helpers.configuration_mocker.ConfigurationMocker - DEBUG - Done generating transformation_variables mocks.
# 2019-05-28 18:36:42,764 - core.helpers.session_helper.SessionHelper - INFO - Done. Created dev session with mock data.

# %%
final_dataframe.head()
# Out:
#          rec_date pharm_code   pharm_npi transtype pharm_transaction_id  \
# 0  20181024115959        ACR  1346208949       COM   279133432018102401
# 1  20181025115959        ACR  1346208949       COM   278370982018102502
# 2  20181029115959        ACR  1346208949       COM   279181482018102903
# 3  20181102115959        ACR  1346208949       COM   267244982018110204
# 4  20181106115959        ACR  1346208949       COM   160618142018110605
#
#   trans_seq ref_source        ref_date program_id pharmacy_id  ...  \
# 0         0     DIRECT  20181019120000       None    27913343  ...
# 1         0     DIRECT  20181022120000       None    27837098  ...
# 2         0     DIRECT  20181024120000       None    27918148  ...
# 3         0     DIRECT  20181030120000       None    26724498  ...
# 4         0     DIRECT  20181102120000       None    16061814  ...
#
#   msa_patient_id msa_patient_bmap __metadata_app_version  \
# 0           None            NNNNV                 0.0.11
# 1           None            NNNVV                 0.0.11
# 2           None            NNNVV                 0.0.11
# 3           None            NNNVV                 0.0.11
# 4           None            NNNVV                 0.0.11
#
#                           __metadata_output_contract brand strength  \
# 0  s3://ichain-dev/stephanie/stephanie/ilumya/enr...  None     None
# 1  s3://ichain-dev/stephanie/stephanie/ilumya/enr...  None     None
# 2  s3://ichain-dev/stephanie/stephanie/ilumya/enr...  None     None
# 3  s3://ichain-dev/stephanie/stephanie/ilumya/enr...  None     None
# 4  s3://ichain-dev/stephanie/stephanie/ilumya/enr...  None     None
#
#   prod_grp_id  uom rx_type __metadata_run_timestamp
# 0         NaN  PEN              2019-05-28 16:02:58
# 1         NaN  PEN              2019-05-28 16:02:58
# 2         NaN  PEN              2019-05-28 16:02:58
# 3         NaN  PEN              2019-05-28 16:02:58
# 4         NaN  PEN              2019-05-28 16:02:58
#
# [5 rows x 75 columns]

# %%
### Use the variables above to execute your transformation. the final output needs to be a variable named final_dataframe

final_dataframe = final_dataframe.query('sub_status == "SHIPMENT"').reset_index()

final_dataframe['ship_date'] = final_dataframe['ship_date'].apply(lambda x: x[0:8])

# %% [markdown]
# ### Publish

# %%
## that's it - just provide the final dataframe to the var final_dataframe and we take it from there
transform.publish_contract.publish(final_dataframe)
# Out:
# 2019-05-28 18:36:56,761 - core.dataset_contract.DatasetContract - INFO - Publishing dataframe to s3 location s3://ichain-dev/stephanie/stephanie/ilumya/enrich/symphony_health_association_filter_shipment_only.
# 2019-05-28 18:36:56,766 - s3parq.publish_parq - INFO - Checking params...
# 2019-05-28 18:36:56,769 - s3parq.publish_parq - INFO - Params valid.
# 2019-05-28 18:36:56,793 - s3parq.publish_parq - INFO - Writing to S3...
